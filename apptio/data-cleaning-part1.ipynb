# %%
import os, glob, gzip
import pandas as pd
from tqdm import tqdm
import json
from datetime import datetime

pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# > #### Iterate through the directory recursively and extract the tar.gz files

# %%
def get_gzip_file_paths(root_dir):
    
    '''
        Gzipped files are where the clickthrough data is stored.
        Collect all the gzip paths recursively starting the traversal
        from the root_directory
        
        @return List of gzips (clickthrough files)
    '''
    
    gzip_file_paths = []
    for subdir, dirs, files in tqdm(os.walk(root_dir)):

        for file in files:
            filepath = os.path.join(subdir, file)
            if filepath.endswith(".gz"):
                gzip_file_paths.append(filepath)
                
    return gzip_file_paths

# %%
def parse_clickthrough_gzip(path):
    
    try:
        df = pd.read_json(path, lines=True, compression='gzip')
        df["filepath"] = path.split("clickstream_data_2016")[1][1:]
        df["request_keys"] = df["request"].apply(lambda x: x.keys())
        df["server_request_keys"] = df["server_request"].apply(lambda x: x.keys())

        request_attributes_all = [list(x) for x in df["request_keys"].tolist()]
        request_attributes = list(set([item for sublist in request_attributes_all for item in sublist]))
        for attribute in request_attributes:
            df[attribute] = df["request"].apply(lambda x: x[attribute] if attribute in x else None)

        serv_request_attributes_all = [list(x) for x in df["server_request_keys"].tolist()]
        serv_request_attributes = list(set([item for sublist in serv_request_attributes_all for item in sublist]))
        for attribute in serv_request_attributes:
            df[attribute] = df["server_request"].apply(lambda x: x[attribute] if attribute in x else None)


        del df["request_keys"]
        del df["server_request_keys"]
        del df["request"]
        del df["server_request"]
        return df
    except:
        return None
        

def read_gzip_files(gzip_file_paths):
    
    '''
    Read the gzipped files into a dataframe and 
    construct the clickthrough attributes.
    
    @return List of dataframes with clickthrough attributes, 
            one for each file
    @return List of dataframes which have
    '''

    json_data = list(map(parse_clickthrough_gzip, gzip_file_paths))
    failed_files = [gzip_file_paths[i] for i, df in enumerate(json_data) if df is None]
    
    return json_data, failed_files

# %% [markdown]
# ### Validation

# %%
def get_all_headers(dfs):
    
    '''
    Most dataframes might not have the full set of keys.
    Get every key which was present in request/ server_request.
    '''
    
    headers = [x.columns.tolist() for x in dfs]
    headers = list(set([item for sublist in headers for item in sublist]))
    return headers


def format_clickthrough_dataframes(df, headers_to_include):

    
    missing_cols = [x for x in headers_to_include if x not in df.columns.tolist()]
    if len(missing_cols) > 0:
        for col in missing_cols:
            df[col] = None
    df = df[headers_to_include]
    return df

# %%
# Ideally this has to be read in from a configuration file. 
# However, reading from a variable for now.
root_directory = '/home/sree/code/apptio-data/clickstream_data_2016'


gzip_paths = get_gzip_file_paths(root_directory)
clickthrough_dfs, failed_files = read_gzip_files(gzip_paths[:4])


headers = get_all_headers(clickthrough_dfs)

# Using all headers for now. Later depending on the usecase, we can use a subset of these
# columns for our analysis
clickthrough_dfs = [format_clickthrough_dataframes(df, headers) for df in clickthrough_dfs]

input_data = pd.concat(clickthrough_dfs)
input_data.head()
# Out:
# 205it [00:00, 36503.18it/s]
#   eventId                                    responseHeaders parentFrameId  \
# 0    None  {'Vary': 'User-Agent', 'Date': 'Wed, 07 Sep 20...             0
# 1    None  {'Date': 'Wed, 07 Sep 2016 00:12:37 GMT', 'Tra...            -1
# 2    None  {'content-type': 'text/html', 'status': '200',...             0
# 3    None  {'Vary': 'User-Agent', 'Date': 'Wed, 07 Sep 20...             0
# 4    None  {'Content-Language': 'en-US', 'Date': 'Wed, 07...            -1
#
#   is_online                         user_guid error  \
# 0      None  2f8b23ca273de94a51281b0697a126d7  None
# 1      None  2f8b23ca273de94a51281b0697a126d7  None
# 2      None  2f8b23ca273de94a51281b0697a126d7  None
# 3      None  2f8b23ca273de94a51281b0697a126d7  None
# 4      None  2f8b23ca273de94a51281b0697a126d7  None
#
#                                    windowTitle  tabId method fromCache  \
# 0                                         None    335    GET     False
# 1                                "NCIS" (2003)    335    GET     False
# 2                                         None    335    GET     False
# 3                                         None    335    GET     False
# 4  NCIS (TV Series 2003â ) - Episodes - IMDb    335    GET      True
#
#                                                  url mainFrameRequestId  \
# 0  http://s.amazon-adsystem.com/iu3?d=imdb.com&a1...               None
# 1  http://www.imdb.com/title/tt0364845/eprate?ref...               None
# 2  https://www.facebook.com/widgets/like.php?widt...               None
# 3  http://s.amazon-adsystem.com/iu3?d=imdb.com&a1...               None
# 4  http://www.imdb.com/title/tt0364845/episodes?r...               None
#
#                                             filepath  \
# 0  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...
# 1  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...
# 2  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...
# 3  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...
# 4  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...
#
#                                       requestHeaders  \
# 0  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...
# 1  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...
# 2  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...
# 3  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...
# 4  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...
#
#                         software_id        partner_id  \
# 0  d2c091f86191954cdf6e24beb1d2092a  1697b2090acdf06d
# 1  d2c091f86191954cdf6e24beb1d2092a  1697b2090acdf06d
# 2  d2c091f86191954cdf6e24beb1d2092a  1697b2090acdf06d
# 3  d2c091f86191954cdf6e24beb1d2092a  1697b2090acdf06d
# 4  d2c091f86191954cdf6e24beb1d2092a  1697b2090acdf06d
#
#                                           user_agent        type  \
# 0  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...   sub_frame
# 1  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...  main_frame
# 2  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...   sub_frame
# 3  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...   sub_frame
# 4  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...  main_frame
#
#         statusLine windowName  \
# 0  HTTP/1.1 200 OK       None
# 1  HTTP/1.1 200 OK
# 2     HTTP/1.1 200       None
# 3  HTTP/1.1 200 OK       None
# 4  HTTP/1.1 200 OK
#
#                                      documentReferer  request_unixtime  \
# 0                                               None        1473207176
# 1  http://www.imdb.com/title/tt0364845/episodes?r...        1473207176
# 2                                               None        1473207159
# 3                                               None        1473207159
# 4  http://www.imdb.com/title/tt0364845/?ref_=nv_sr_1        1473207159
#
#   redirectUrl     timeStamp country_code statusCode frameId navigationId  \
# 0        None  1.473207e+12           US        200    3807         None
# 1        None  1.473207e+12           US        200       0         None
# 2        None  1.473207e+12           US        200    3799         None
# 3        None  1.473207e+12           US        200    3801         None
# 4        None  1.473207e+12           US        200       0         None
#
#   requestType               ip x_forwarded_for  \
# 0        main     54.239.31.89  69.207.104.248
# 1        main  207.171.162.180  69.207.104.248
# 2        main      31.13.71.36  69.207.104.248
# 3        main     54.239.31.89  69.207.104.248
# 4        main  207.171.162.180  69.207.104.248
#
#                                             user_map accept_language  \
# 0  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}  en-US,en;q=0.8
# 1  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}  en-US,en;q=0.8
# 2  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}  en-US,en;q=0.8
# 3  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}  en-US,en;q=0.8
# 4  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}  en-US,en;q=0.8
#
#   openerTabId requestId
# 0        None     46079
# 1        None     46030
# 2        None     46001
# 3        None     46002
# 4        None     45987

# %% [markdown]
#     0. Has gzip files been corrupted
#     1. No empty files
#     2. Has all mandatory columns
#     3. See if the filepath url is valid
#     4. check for a filter condition

# %%
input_data.shape
# Out:
# (5484, 35)

# %% [markdown]
# # Make sure that all columns exist in all the dataframes

# %% [markdown]
# ## Convert the timestamps to an understandable format

# %%
input_data["request_datetime"] = input_data["request_unixtime"].apply(lambda x: datetime.fromtimestamp(x))
input_data.head()
# Out:
#   accept_language country_code  \
# 0  en-US,en;q=0.8           US
# 1  en-US,en;q=0.8           US
# 2  en-US,en;q=0.8           US
# 3  en-US,en;q=0.8           US
# 4  en-US,en;q=0.8           US
#
#                                      documentReferer error eventId  \
# 0                                               None  None    None
# 1  http://www.imdb.com/title/tt0364845/episodes?r...  None    None
# 2                                               None  None    None
# 3                                               None  None    None
# 4  http://www.imdb.com/title/tt0364845/?ref_=nv_sr_1  None    None
#
#                                             filepath frameId fromCache  \
# 0  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...    3807     False
# 1  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...       0     False
# 2  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...    3799     False
# 3  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...    3801     False
# 4  09/07/00/US/CR/1697b2090acdf06d/part-00014-000...       0      True
#
#                 ip is_online mainFrameRequestId method navigationId  \
# 0     54.239.31.89      None               None    GET         None
# 1  207.171.162.180      None               None    GET         None
# 2      31.13.71.36      None               None    GET         None
# 3     54.239.31.89      None               None    GET         None
# 4  207.171.162.180      None               None    GET         None
#
#   openerTabId parentFrameId        partner_id redirectUrl  \
# 0        None             0  1697b2090acdf06d        None
# 1        None            -1  1697b2090acdf06d        None
# 2        None             0  1697b2090acdf06d        None
# 3        None             0  1697b2090acdf06d        None
# 4        None            -1  1697b2090acdf06d        None
#
#                                       requestHeaders requestId requestType  \
# 0  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...     46079        main
# 1  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...     46030        main
# 2  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...     46001        main
# 3  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...     46002        main
# 4  {'Upgrade-Insecure-Requests': '1', 'Accept-Lan...     45987        main
#
#    request_unixtime                                    responseHeaders  \
# 0        1473207176  {'Vary': 'User-Agent', 'Date': 'Wed, 07 Sep 20...
# 1        1473207176  {'Date': 'Wed, 07 Sep 2016 00:12:37 GMT', 'Tra...
# 2        1473207159  {'content-type': 'text/html', 'status': '200',...
# 3        1473207159  {'Vary': 'User-Agent', 'Date': 'Wed, 07 Sep 20...
# 4        1473207159  {'Content-Language': 'en-US', 'Date': 'Wed, 07...
#
#                         software_id statusCode       statusLine  tabId  \
# 0  d2c091f86191954cdf6e24beb1d2092a        200  HTTP/1.1 200 OK    335
# 1  d2c091f86191954cdf6e24beb1d2092a        200  HTTP/1.1 200 OK    335
# 2  d2c091f86191954cdf6e24beb1d2092a        200     HTTP/1.1 200    335
# 3  d2c091f86191954cdf6e24beb1d2092a        200  HTTP/1.1 200 OK    335
# 4  d2c091f86191954cdf6e24beb1d2092a        200  HTTP/1.1 200 OK    335
#
#       timeStamp        type  \
# 0  1.473207e+12   sub_frame
# 1  1.473207e+12  main_frame
# 2  1.473207e+12   sub_frame
# 3  1.473207e+12   sub_frame
# 4  1.473207e+12  main_frame
#
#                                                  url  \
# 0  http://s.amazon-adsystem.com/iu3?d=imdb.com&a1...
# 1  http://www.imdb.com/title/tt0364845/eprate?ref...
# 2  https://www.facebook.com/widgets/like.php?widt...
# 3  http://s.amazon-adsystem.com/iu3?d=imdb.com&a1...
# 4  http://www.imdb.com/title/tt0364845/episodes?r...
#
#                                           user_agent  \
# 0  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 1  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 2  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 3  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 4  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
#
#                           user_guid  \
# 0  2f8b23ca273de94a51281b0697a126d7
# 1  2f8b23ca273de94a51281b0697a126d7
# 2  2f8b23ca273de94a51281b0697a126d7
# 3  2f8b23ca273de94a51281b0697a126d7
# 4  2f8b23ca273de94a51281b0697a126d7
#
#                                             user_map windowName  \
# 0  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}       None
# 1  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}
# 2  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}       None
# 3  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}       None
# 4  {'tiger': '0b3cefeb-182c-9f91-b3ae-836baaa448c8'}
#
#                                    windowTitle x_forwarded_for  \
# 0                                         None  69.207.104.248
# 1                                "NCIS" (2003)  69.207.104.248
# 2                                         None  69.207.104.248
# 3                                         None  69.207.104.248
# 4  NCIS (TV Series 2003â ) - Episodes - IMDb  69.207.104.248
#
#      request_datetime
# 0 2016-09-06 20:12:56
# 1 2016-09-06 20:12:56
# 2 2016-09-06 20:12:39
# 3 2016-09-06 20:12:39
# 4 2016-09-06 20:12:39

# %% [markdown]
# #### Profile this data (pandas profiling works better here, unfortunately a system error stops me from doing this)
